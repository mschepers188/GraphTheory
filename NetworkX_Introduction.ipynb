# %%
import networkx as nx
import pandas as pd
import numpy as np

# %%
G = nx.Graph()
G.add_edge('A', 'B', weight=13, relation='friend')
G.add_edge('C', 'B', weight=7, relation='friend')
G.add_edge('C', 'A', weight=20, relation='friend')
G.add_node('A', role='Trader')
G.add_node('B', role='Analyst')
G.add_node('C', role='Manager')
nx.draw_networkx(G, with_labels=True)k

# %%
nodes = ['A', 'B', 'C', 'D']
edges = [('A','B', {'weight':4}),
        ('A','C',{'weight':2}),
        ('B','C',{'weight':1}),
        ('B','D', {'weight':5}),
        ('C','D', {'weight':8})]

G = nx.Graph()
# for node in nodes:
#     G.add_node(node)
G.add_nodes_from(nodes)
G.add_edges_from(edges)
    
nx.draw_networkx(G, with_labels=True)
print(G.edges(data=True))
# Out:
# [('A', 'B', {'weight': 4}), ('A', 'C', {'weight': 2}), ('B', 'C', {'weight': 1}), ('B', 'D', {'weight': 5}), ('C', 'D', {'weight': 8})]

# %%
routemap =  [('St. Louis', 'Miami'), ('St. Louis', 'San Diego'), ('St. Louis', 'Chicago'),
             ('San Diego', 'Chicago'), ('San Diego', 'San Francisco'), ('San Diego', 'Minneapolis'),
             ('San Diego', 'Boston'), ('San Diego', 'Portland'), ('San Diego', 'Seattle'),
             ('Tulsa', 'New York'), ('Tulsa', 'Dallas'), ('Phoenix', 'Cleveland'), 
             ('Phoenix', 'Denver'), ('Phoenix', 'Dallas'), ('Chicago', 'New York'), 
             ('Chicago', 'Los Angeles'), ('Miami', 'New York'), ('Miami', 'Philadelphia'),
             ('Miami', 'Denver'), ('Boston', 'Atlanta'), ('Dallas', 'Cleveland'),
             ('Dallas', 'Albuquerque'), ('Philadelphia', 'Atlanta'), ('Denver', 'Minneapolis'),
             ('Denver', 'Cleveland'), ('Albuquerque', 'Atlanta'), ('Minneapolis', 'Portland'),
             ('Los Angeles', 'Seattle'), ('San Francisco', 'Portland'), ('San Francisco', 'Seattle'),
             ('San Francisco', 'Cleveland'), ('Seattle', 'Portland')]

Gr = nx.Graph()
Gr.add_edges_from(routemap)


# help(nx.draw_networkx)

nx.draw_spring(Gr, with_labels=True)
